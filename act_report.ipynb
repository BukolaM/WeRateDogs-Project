# %% [markdown]
# ## WeRateDogs
# ###### By Bukola Ajayi

# %%
from IPython.display import HTML, display
imagesList="<div style='width:806px;'>\
<div style='width: 400px; height:300px; margin: 0px; float:left; border: 1px solid black;overflow:hidden' >\
<img style='width: 400px; margin:0px auto;' src='https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg' />\
</div>\
<div style='width: 400px; height:530px; margin: 0px; float:right; border: 1px solid black;overflow:hidden' >\
<img style='width: 400px; margin:0px auto;' src='https://pbs.twimg.com/media/CT5m4VGWEAAtKc8.jpg' />\
</div>\
<div style='width: 400px; height:400px; margin: 0px; float:left; border: 1px solid black;overflow:hidden' >\
<img style='width: 400px; margin:0px auto;' src='https://pbs.twimg.com/media/CUELa0NUkAAscGC.jpg' />\
</div>\
<div style='width: 200px; height:170px; margin: 0px; float:left; border: 1px solid black; overflow:hidden' >\
<img style='width: 200px; margin:0px auto;' src='https://pbs.twimg.com/media/CUES51dXIAEahyG.jpg' />\
</div>\
<div style='width: 200px; height:170px; margin: 0px; float:left; border: 1px solid black; overflow:hidden' >\
<img style='width: 200px; margin:0px auto;' src='https://pbs.twimg.com/media/CUC74aTWoAInZey.jpg' />\
</div><div style='clear:both;' ></div></div>"
html_file = HTML(imagesList)
display(html_file)
# Out:
# <div style='width:806px;'><div style='width: 400px; height:300px; margin: 0px; float:left; border: 1px solid black;overflow:hidden' ><img style='width: 400px; margin:0px auto;' src='https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg' /></div><div style='width: 400px; height:530px; margin: 0px; float:right; border: 1px solid black;overflow:hidden' ><img style='width: 400px; margin:0px auto;' src='https://pbs.twimg.com/media/CT5m4VGWEAAtKc8.jpg' /></div><div style='width: 400px; height:400px; margin: 0px; float:left; border: 1px solid black;overflow:hidden' ><img style='width: 400px; margin:0px auto;' src='https://pbs.twimg.com/media/CUELa0NUkAAscGC.jpg' /></div><div style='width: 200px; height:170px; margin: 0px; float:left; border: 1px solid black; overflow:hidden' ><img style='width: 200px; margin:0px auto;' src='https://pbs.twimg.com/media/CUES51dXIAEahyG.jpg' /></div><div style='width: 200px; height:170px; margin: 0px; float:left; border: 1px solid black; overflow:hidden' ><img style
# ...

# %% [markdown]
# This project is focusing on providing insights and visualisations from data gotten from WeRateDogs Twitter.
#
# We would also be making use of "image_predictions.tsv" hosted by Udacity to enhance the data gotten and use the predictions to make informed decisions.
#
# We will be drawing some insight from the analysis done on this project.

# %% [markdown]
# ### Processing our Data
#
# The "WeRateDogs" Twitter archive enhanced csv: This file will be downloaded manually by clicking the following link provided.
#
# The tweet image predictions tsv: This file image_predictions.tsv is hosted on Udacity's servers and will be downloaded progamatically as well, following the link provided;
#
# Using the tweet ID's gotten from the WeRateDogs Twitter archive csv, we will query the Twitter API for each tweet's JSON data using Python's Tweepy library and store each tweet's entire set of JSON data in a file called tweet_json.txtstored as a txt file.
#
# This gives a total of three files.
#
# These three files were analyzed, cleaned up, and then brought together by merging them based on their unique identifiers to give a clean master file which was used for our analysis

# %% [markdown]
# ### Percentage prediction of a dog to be true
#
# According to the data gotten, we observed that not all predictions were dogs, so the success rate of dog prediction became apparent. We would see that 60% success rate for all prediction was true.

# %%
from IPython.display import Image
Image(filename='files/prediction-success-rate.png')

# %% [markdown]
# ### The 20 most popular tweeted dog breeds
#
# > A total of 379 dogs were identified however, after drawing visualisation and gotten insight on the top 20 popular dogs mostly tweeted about, the image below indicates that the golden retriever breed tops the list.

# %%
from IPython.display import HTML
HTML(filename='files/the-20-image-samples-of-the-most-tweeted-dog-breed.html')
# Out:
# <div style='width: 200px; height:200px; margin: 0px; float:left; border: 1px solid black;' >                         <img style='width: 120px; margin:0px auto;' src='https://pbs.twimg.com/media/DFg_2PVW0AEHN3p.jpg' />                         <div style='text-align:center' >golden_retriever</div>                     </div><div style='width: 200px; height:200px; margin: 0px; float:left; border: 1px solid black;' >                         <img style='width: 120px; margin:0px auto;' src='https://pbs.twimg.com/media/C4bTH6nWMAAX_bJ.jpg' />                         <div style='text-align:center' >Labrador_retriever</div>                     </div><div style='width: 200px; height:200px; margin: 0px; float:left; border: 1px solid black;' >                         <img style='width: 120px; margin:0px auto;' src='https://pbs.twimg.com/media/DFrEyVuW0AAO3t9.jpg' />                         <div style='text-align:center' >Pembroke</div>                     </div><div style='width: 200px; height:20
# ...

# %% [markdown]
# ### Most tweeted 'Dog Stage'
# > Some of the tweets contains multiple dog stages as some of the tweet contains several dogs. The following graph shows the most tweeted dog stages. We can clearly see that the doggo,puppo stage has the highest average dog ratings.

# %%
from IPython.display import Image
Image(filename='files/the-average-ratings-for-the-different-dog-stages.png')

# %% [markdown]
# ###  The top 20 dog breeds based on retweet and likes
# > As both of the visualizations of below shows, the top 20 most common dogs on WeRateDogs coincide with the most favorite and retweet dog breed. It can be seen that Golden retriever is the most popular dog and it along with Labrador Retriever, Pembroke, Chihuahua and Samoyed complete the top 5 common dog breeds in the data.

# %%
from IPython.display import Image
Image(filename='files/top 20-dog-breeds-based-on-their-retweet-count.png')

# %%
from IPython.display import Image
Image(filename='files/top-20-dog-breeds-based-on-their-favorite-count.png')

# %%
from IPython.display import Image
Image(filename='files/favorite_dog.png')

# %% [markdown]
# Sample image of Golden retriever breed gotten from the dataset

# %% [markdown]
# ### The most used devices in this twitter project
#
# > The following bar plot shows that most users are iPhone users, the indicates that the largest portion of our dog lovers were iPhone users.

# %%
from IPython.display import Image
Image(filename='files/tweet-sources.png')

# %% [markdown]
# ###  The top 20 dog breeds based on retweet and likes
# As both of the visualizations of below shows, the top 20 most common dogs on WeRateDogs coincide with the most favorite and retweet dog breed. It can be seen that Golden retriever is the most popular dog and it along with Labrador Retriever, Pembroke, Chihuahua and Pugs complete the top 5 common dog breeds in the data.

# %% [markdown]
# From the other insights derived from this analysis, I found that there is a strong positive relationship between the favourites count and the retweets count of a given tweet.

# %% [markdown]
# ## Conclusion
#
# This project was mostly a data wrangling project. During the course of the data cleaning, all identified issues have been fixed, and I have also merged separated data frames into one and added some missing values. The final data frame was stored as twitter_archive_master.csv. From the overall exploratory analysis, certain conclusions have been drawn, which include the following:
#
# Based on the data gathered, I have assessed the most evident issues (17 issues in total) and documented them to create a record of modifications. Later, in the data cleaning process, I fixed all identified issues to complete, and I also merged separated data frames into one and added some missing values. The final data frame was stored as twitter_archive_master.csv.
#
# The Golden Retriever breed, which seems to be a popular choice for pet dogs, is the most liked dog based on its interestingly high retweet and favourite count.
#
# There is a strong linear relationship between the number of favourites and the number of retweets of a tweet, with a positive correlation coefficient of 0.86. This relationship might already be established as people will favourite what they retweet or the other way around.
#
# The Doggo stage has the highest average ratings.
#
# The dog breed with the highest average rating is the clumber. This indicates that the average rating of a dog is independent of the retweets and the likes.

# %% [markdown]
# <!-- #### Additional Info
# #### For further information about Project, you can access the following link:
# <a href= "http://localhost:8888/notebooks/%20wrangle_act.ipynb"> click me </a>
#
# <!-- ND111 - Project 02 - Repository (Github Repository)
# ND111 - Project 02 - Wrangle Act (Jupyter Notebook File)
# ND111 - Project 02 - Wrangle Report (Markdown File)
# ND111 - Data Science II - Nanodegree Repository (Github Repository) -->

# %% [markdown]
# <!-- ##### Additional Info
# For further information about the Project,
# <a href = "http://localhost:8888/notebooks/%20wrangle_act.ipynb"> click me </a>
#
# - Wrangle-WeRateDogs-Twitter - Repository (Github Repository)
# - Wrangle-WeRateDogs-Twitter - Wrangle Act (Jupyter Notebook File)
#
# Wrangle-WeRateDogs-Twitter - Wrangle Report (Wrangle Report) -->
